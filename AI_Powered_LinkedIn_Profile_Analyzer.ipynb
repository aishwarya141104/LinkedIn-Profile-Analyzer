# %%
# !pip install google-generativeai
# !pip install reportlab

# %%
import google.generativeai as genai

from reportlab.platypus import SimpleDocTemplate
from reportlab.platypus import Paragraph
from reportlab.lib.styles import getSampleStyleSheet

# %%
API_KEY = "AQ.Ab8RN6IsS3XMEhHEtN274GQYBso7wpz_ddNNg_n-3C-kC0yeQA"

genai.configure(api_key=API_KEY)

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
headline = "Computer Engineering Student | Web Developer | AI Enthusiast"

about = "Passionate computer engineering student with interest in AI, Data Analytics and Web Development."

skills = "Python, HTML, CSS, JavaScript, SQL, Power BI"

experience = "Completed projects in Data Analytics and Web Development. Participated in internships and workshops."

# %%
prompt = f"""
Analyze the LinkedIn profile below.

Headline:
{headline}

About:
{about}

Skills:
{skills}

Experience:
{experience}

Evaluate:

1. Headline Quality (/10)
2. About Section (/10)
3. Skills Section (/10)
4. Experience Section (/10)
5. Recruiter Keywords
6. Resume Alignment
7. Overall LinkedIn Score (/100)
8. Improvement Suggestions

Generate a professional report.
"""

# %%
# !pip install -U google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AQ.Ab8RN6IsS3XMEhHEtN274GQYBso7wpz_ddNNg_n-3C-kC0yeQA")

for m in genai.list_models():
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.5-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# ...

# %%
response = model.generate_content(prompt)

report = response.text

print(report)
# Out:
# ## LinkedIn Profile Analysis Report
#
# **Profile Evaluated:** Computer Engineering Student Profile Snippet
# **Date of Analysis:** October 26, 2023
#
# ---
#
# ### Introduction
#
# This report provides a comprehensive analysis of the provided LinkedIn profile snippet, evaluating its effectiveness in professional branding, keyword optimization, and overall impact for a computer engineering student seeking opportunities in Web Development and AI.
#
# ### Profile Overview
#
# The profile presents a foundational presence with clear stated interests and a basic list of technical skills. While it establishes the user's field and aspirations, it currently lacks the depth, detail, and strategic optimization necessary to stand out effectively to recruiters and network with industry professionals.
#
# ---
#
# ### Detailed Section Analysis
#
# #### 1. Headline Quality: 6/10
#
# ...

# %%
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.lib.styles import getSampleStyleSheet

pdf = SimpleDocTemplate("LinkedIn_Report.pdf")

styles = getSampleStyleSheet()

content = [
    Paragraph(report.replace("\n", "<br/>"),
              styles["BodyText"])
]

pdf.build(content)

print("PDF Created Successfully!")
# Out:
# PDF Created Successfully!

# %%
from google.colab import files

files.download("LinkedIn_Report.pdf")
